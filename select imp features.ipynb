# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/predicting-coupon-redemption/Datasets columns explanation_.docx
# /kaggle/input/predicting-coupon-redemption/test.csv
# /kaggle/input/predicting-coupon-redemption/train/train.csv
# /kaggle/input/predicting-coupon-redemption/train/campaign_data.csv
# /kaggle/input/predicting-coupon-redemption/train/customer_demographics.csv
# /kaggle/input/predicting-coupon-redemption/train/item_data.csv
# /kaggle/input/predicting-coupon-redemption/train/customer_transaction_data.csv
# /kaggle/input/predicting-coupon-redemption/train/coupon_item_mapping.csv

# %%
import seaborn as sns

# %%
# Viewing training dataset
train_df=pd.read_csv('/kaggle/input/predicting-coupon-redemption/train/train.csv')
train_df
# Out:
#            id  campaign_id  coupon_id  customer_id  redemption_status
# 0           1           13         27         1053                  0
# 1           2           13        116           48                  0
# 2           6            9        635          205                  0
# 3           7           13        644         1050                  0
# 4           9            8       1017         1489                  0
# ...       ...          ...        ...          ...                ...
# 78364  128587            8         71         1523                  0
# 78365  128589           30        547          937                  0
# 78366  128590            8        754         1004                  0
# 78367  128592           13        134           71                  0
# 78368  128595           13        681          623                  0
#
# [78369 rows x 5 columns]

# %%
#checking for null values in training dataset
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78369 entries, 0 to 78368
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 78369 non-null  int64
#  1   campaign_id        78369 non-null  int64
#  2   coupon_id          78369 non-null  int64
#  3   customer_id        78369 non-null  int64
#  4   redemption_status  78369 non-null  int64
# dtypes: int64(5)
# memory usage: 3.0 MB

# %%
# Viewing test dataset
test_df=pd.read_csv('/kaggle/input/predicting-coupon-redemption/test.csv')
test_df
# Out:
#            id  campaign_id  coupon_id  customer_id
# 0           3           22        869          967
# 1           4           20        389         1566
# 2           5           22        981          510
# 3           8           25       1069          361
# 4          10           17        498          811
# ...       ...          ...        ...          ...
# 50221  128584           20        843          501
# 50222  128588           25        415          481
# 50223  128591           25        596         1336
# 50224  128593           22        518          748
# 50225  128594           18        988          851
#
# [50226 rows x 4 columns]

# %%
# checking for null values in test dataset
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50226 entries, 0 to 50225
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           50226 non-null  int64
#  1   campaign_id  50226 non-null  int64
#  2   coupon_id    50226 non-null  int64
#  3   customer_id  50226 non-null  int64
# dtypes: int64(4)
# memory usage: 1.5 MB

# %%
#Customer transaction dataset
cus_tsc_df=pd.read_csv('/kaggle/input/predicting-coupon-redemption/train/customer_transaction_data.csv')
cus_tsc_df
# Out:
#                date  customer_id  item_id  quantity  selling_price  \
# 0        2012-01-02         1501    26830         1          35.26
# 1        2012-01-02         1501    54253         1          53.43
# 2        2012-01-02         1501    31962         1         106.50
# 3        2012-01-02         1501    33647         1          67.32
# 4        2012-01-02         1501    48199         1          71.24
# ...             ...          ...      ...       ...            ...
# 1324561  2013-06-30         1129     2777         1         284.60
# 1324562  2013-06-30         1129     2953         4          42.74
# 1324563  2013-06-30         1129     2971         6          64.12
# 1324564  2013-06-30         1129    46984         1          95.82
# 1324565  2013-06-30         1129    64498         2         489.78
#
#          other_discount  coupon_discount
# 0                -10.69              0.0
# 1                -13.89              0.0
# 2                -14.25              0.0
# 3                  0.00              0.0
# 4                -28.14              0.0
# ...                 ...              ...
# 1324561          -71.24              0.0
# 1324562          -28.50              0.0
# 1324563          -42.74              0.0
# 1324564            0.00              0.0
# 1324565            0.00              0.0
#
# [1324566 rows x 7 columns]

# %%
# checking for null values in customer demographics dataset
cus_tsc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1324566 entries, 0 to 1324565
# Data columns (total 7 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   date             1324566 non-null  object
#  1   customer_id      1324566 non-null  int64
#  2   item_id          1324566 non-null  int64
#  3   quantity         1324566 non-null  int64
#  4   selling_price    1324566 non-null  float64
#  5   other_discount   1324566 non-null  float64
#  6   coupon_discount  1324566 non-null  float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 70.7+ MB

# %%
cus_tsc_df=cus_tsc_df.sample(n=5000)
cus_tsc_df
# Out:
#                date  customer_id  item_id  quantity  selling_price  \
# 171616   2012-05-09         1490    13776         1          69.46
# 1121836  2013-04-19          367    11362         1          14.96
# 511133   2012-09-14          432    29847         2          71.24
# 632090   2012-10-25         1555    10789         2         156.02
# 750834   2012-12-07         1109    10952         1          31.70
# ...             ...          ...      ...       ...            ...
# 168733   2012-05-08          561    13915         2         177.39
# 705969   2012-11-20          570    47965         1          89.05
# 69536    2012-03-23          152     4685         4          84.06
# 667764   2012-11-08         1424    17402         2         142.48
# 109093   2012-04-13          601    32563         1          28.14
#
#          other_discount  coupon_discount
# 171616             0.00              0.0
# 1121836            0.00              0.0
# 511133           -34.91              0.0
# 632090          -128.23              0.0
# 750834             0.00              0.0
# ...                 ...              ...
# 168733             0.00              0.0
# 705969           -38.83              0.0
# 69536            -56.99              0.0
# 667764             0.00              0.0
# 109093             0.00              0.0
#
# [5000 rows x 7 columns]

# %%
# selecting features with high importance only
cus_tsc_df= cus_tsc_df.drop(['date','item_id'],axis=1)
cus_tsc_df
# Out:
#          customer_id  quantity  selling_price  other_discount  coupon_discount
# 171616          1490         1          69.46            0.00              0.0
# 1121836          367         1          14.96            0.00              0.0
# 511133           432         2          71.24          -34.91              0.0
# 632090          1555         2         156.02         -128.23              0.0
# 750834          1109         1          31.70            0.00              0.0
# ...              ...       ...            ...             ...              ...
# 168733           561         2         177.39            0.00              0.0
# 705969           570         1          89.05          -38.83              0.0
# 69536            152         4          84.06          -56.99              0.0
# 667764          1424         2         142.48            0.00              0.0
# 109093           601         1          28.14            0.00              0.0
#
# [5000 rows x 5 columns]

# %%
# merging train_df and cus_tsc_df
train_tsc_df=pd.merge(train_df,cus_tsc_df,left_on='customer_id',right_on='customer_id')

# merging test_df and cus_tsc_df
test_tsc_df=pd.merge(test_df, cus_tsc_df, left_on='customer_id',right_on='customer_id')

# %%
test_tsc_df
# Out:
#             id  campaign_id  coupon_id  customer_id  quantity  selling_price  \
# 0            3           22        869          967         1         302.41
# 1            3           22        869          967         1         117.19
# 2            3           22        869          967         2         234.38
# 3            3           22        869          967         1          53.43
# 4            3           22        869          967         1          95.46
# ...        ...          ...        ...          ...       ...            ...
# 228421  123403           24         42         1424         1          24.58
# 228422  123403           24         42         1424         1          74.45
# 228423  123403           24         42         1424         2         142.48
# 228424   50974           24         42         1286         1          53.07
# 228425   69055           24         43         1286         1          53.07
#
#         other_discount  coupon_discount
# 0                 0.00              0.0
# 1                -7.48              0.0
# 2               -28.50              0.0
# 3               -10.33              0.0
# 4                 0.00              0.0
# ...                ...              ...
# 228421          -10.69              0.0
# 228422            0.00              0.0
# 228423            0.00              0.0
# 228424           -7.12              0.0
# 228425           -7.12              0.0
#
# [228426 rows x 8 columns]

# %%
train_tsc_df
# Out:
#             id  campaign_id  coupon_id  customer_id  redemption_status  \
# 0            2           13        116           48                  0
# 1            2           13        116           48                  0
# 2         6959           13        992           48                  0
# 3         6959           13        992           48                  0
# 4         8549           13        150           48                  0
# ...        ...          ...        ...          ...                ...
# 306134   49969           26       1013          472                  0
# 306135   61021           26        466          472                  0
# 306136   66541           26        453          472                  0
# 306137  107584           26        545          472                  0
# 306138  122644           26        752          472                  0
#
#         quantity  selling_price  other_discount  coupon_discount
# 0              2          21.37          -21.37              0.0
# 1              1          35.62          -28.14              0.0
# 2              2          21.37          -21.37              0.0
# 3              1          35.62          -28.14              0.0
# 4              2          21.37          -21.37              0.0
# ...          ...            ...             ...              ...
# 306134         2         106.86          -49.16              0.0
# 306135         2         106.86          -49.16              0.0
# 306136         2         106.86          -49.16              0.0
# 306137         2         106.86          -49.16              0.0
# 306138         2         106.86          -49.16              0.0
#
# [306139 rows x 9 columns]

# %%
#Customer demographics dataset
cus_dem_df=pd.read_csv('/kaggle/input/predicting-coupon-redemption/train/customer_demographics.csv')
cus_dem_df
# Out:
#      customer_id age_range marital_status  rented family_size no_of_children  \
# 0              1       70+        Married       0           2            NaN
# 1              6     46-55        Married       0           2            NaN
# 2              7     26-35            NaN       0           3              1
# 3              8     26-35            NaN       0           4              2
# 4             10     46-55         Single       0           1            NaN
# ..           ...       ...            ...     ...         ...            ...
# 755         1577     36-45            NaN       0           2            NaN
# 756         1578     46-55        Married       0           3              1
# 757         1579     46-55            NaN       0           1            NaN
# 758         1580     26-35            NaN       0           2            NaN
# 759         1581     26-35            NaN       0           3              1
#
#      income_bracket
# 0                 4
# 1                 5
# 2                 3
# 3                 6
# 4                 5
# ..              ...
# 755               5
# 756               6
# 757               4
# 758               5
# 759               1
#
# [760 rows x 7 columns]

# %%
# checking for null values in customer demographics dataset
cus_dem_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     760 non-null    int64
#  1   age_range       760 non-null    object
#  2   marital_status  431 non-null    object
#  3   rented          760 non-null    int64
#  4   family_size     760 non-null    object
#  5   no_of_children  222 non-null    object
#  6   income_bracket  760 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 41.7+ KB

# %%
#preprocessing dataset: replacing null values
cus_dem_df['no_of_children'].replace({np.NaN:0},inplace=True)
cus_dem_df['marital_status'].replace({np.NaN:'Unknown'},inplace=True)

# %%
# Again, checking for null values after preprocessing customer demographics dataset
cus_dem_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     760 non-null    int64
#  1   age_range       760 non-null    object
#  2   marital_status  760 non-null    object
#  3   rented          760 non-null    int64
#  4   family_size     760 non-null    object
#  5   no_of_children  760 non-null    object
#  6   income_bracket  760 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 41.7+ KB

# %%
# Selecting features with high importance only
cus_dem_df= cus_dem_df[['customer_id','rented','income_bracket']]
cus_dem_df
# Out:
#      customer_id  rented  income_bracket
# 0              1       0               4
# 1              6       0               5
# 2              7       0               3
# 3              8       0               6
# 4             10       0               5
# ..           ...     ...             ...
# 755         1577       0               5
# 756         1578       0               6
# 757         1579       0               4
# 758         1580       0               5
# 759         1581       0               1
#
# [760 rows x 3 columns]

# %%
# merging train_tsc_df and cus_dem_df
train_tsc_dem_df=pd.merge(train_tsc_df,cus_dem_df,left_on='customer_id',right_on='customer_id')

# merging test_tsc_df and cus_dem_df
test_tsc_dem_df=pd.merge(test_tsc_df, cus_dem_df, left_on='customer_id',right_on='customer_id')

# %%
train_tsc_dem_df
# Out:
#             id  campaign_id  coupon_id  customer_id  redemption_status  \
# 0            2           13        116           48                  0
# 1            2           13        116           48                  0
# 2         6959           13        992           48                  0
# 3         6959           13        992           48                  0
# 4         8549           13        150           48                  0
# ...        ...          ...        ...          ...                ...
# 197061  118711           26          2          507                  0
# 197062  118711           26          2          507                  0
# 197063  128256           26        629          507                  0
# 197064  128256           26        629          507                  0
# 197065  128256           26        629          507                  0
#
#         quantity  selling_price  other_discount  coupon_discount  rented  \
# 0              2          21.37          -21.37              0.0       0
# 1              1          35.62          -28.14              0.0       0
# 2              2          21.37          -21.37              0.0       0
# 3              1          35.62          -28.14              0.0       0
# 4              2          21.37          -21.37              0.0       0
# ...          ...            ...             ...              ...     ...
# 197061         1         104.72            0.00              0.0       0
# 197062         2         142.48         -141.77              0.0       0
# 197063         1          71.24           -6.77              0.0       0
# 197064         1         104.72            0.00              0.0       0
# 197065         2         142.48         -141.77              0.0       0
#
#         income_bracket
# 0                    3
# 1                    3
# 2                    3
# 3                    3
# 4                    3
# ...                ...
# 197061               6
# 197062               6
# 197063               6
# 197064               6
# 197065               6
#
# [197066 rows x 11 columns]

# %%
test_tsc_dem_df
# Out:
#             id  campaign_id  coupon_id  customer_id  quantity  selling_price  \
# 0            3           22        869          967         1         302.41
# 1            3           22        869          967         1         117.19
# 2            3           22        869          967         2         234.38
# 3            3           22        869          967         1          53.43
# 4            3           22        869          967         1          95.46
# ...        ...          ...        ...          ...       ...            ...
# 155624  123403           24         42         1424         1          88.69
# 155625  123403           24         42         1424         2         142.12
# 155626  123403           24         42         1424         1          24.58
# 155627  123403           24         42         1424         1          74.45
# 155628  123403           24         42         1424         2         142.48
#
#         other_discount  coupon_discount  rented  income_bracket
# 0                 0.00              0.0       0               5
# 1                -7.48              0.0       0               5
# 2               -28.50              0.0       0               5
# 3               -10.33              0.0       0               5
# 4                 0.00              0.0       0               5
# ...                ...              ...     ...             ...
# 155624            0.00              0.0       0               5
# 155625         -142.12              0.0       0               5
# 155626          -10.69              0.0       0               5
# 155627            0.00              0.0       0               5
# 155628            0.00              0.0       0               5
#
# [155629 rows x 10 columns]

# %%
#Campaign dataset
camp_df=pd.read_csv('/kaggle/input/predicting-coupon-redemption/train/campaign_data.csv')
camp_df
# Out:
#     campaign_id campaign_type start_date  end_date
# 0            24             Y   21/10/13  20/12/13
# 1            25             Y   21/10/13  22/11/13
# 2            20             Y   07/09/13  16/11/13
# 3            23             Y   08/10/13  15/11/13
# 4            21             Y   16/09/13  18/10/13
# 5            22             X   16/09/13  18/10/13
# 6            18             X   10/08/13  04/10/13
# 7            19             Y   26/08/13  27/09/13
# 8            17             Y   29/07/13  30/08/13
# 9            16             Y   15/07/13  16/08/13
# 10           13             X   19/05/13  05/07/13
# 11           11             Y   22/04/13  07/06/13
# 12           12             Y   22/04/13  24/05/13
# 13           10             Y   08/04/13  10/05/13
# 14            9             Y   11/03/13  12/04/13
# 15            8             X   16/02/13  05/04/13
# 16            7             Y   02/02/13  08/03/13
# 17            6             Y   28/01/13  01/03/13
# 18            3             Y   22/12/12  16/02/13
# 19            5             Y   12/01/13  15/02/13
# 20            4             Y   07/01/13  08/02/13
# 21            1             Y   12/12/12  18/01/13
# 22            2             Y   17/12/12  18/01/13
# 23           30             X   19/11/12  04/01/13
# 24           29             Y   08/10/12  30/11/12
# 25           28             Y   16/09/12  16/11/12
# 26           27             Y   25/08/12  27/10/12
# 27           26             X   12/08/12  21/09/12

# %%
camp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   campaign_id    28 non-null     int64
#  1   campaign_type  28 non-null     object
#  2   start_date     28 non-null     object
#  3   end_date       28 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.0+ KB

# %%
# Selecting features with high importance only
camp_df=camp_df[['campaign_id','campaign_type']]
camp_df
# Out:
#     campaign_id campaign_type
# 0            24             Y
# 1            25             Y
# 2            20             Y
# 3            23             Y
# 4            21             Y
# 5            22             X
# 6            18             X
# 7            19             Y
# 8            17             Y
# 9            16             Y
# 10           13             X
# 11           11             Y
# 12           12             Y
# 13           10             Y
# 14            9             Y
# 15            8             X
# 16            7             Y
# 17            6             Y
# 18            3             Y
# 19            5             Y
# 20            4             Y
# 21            1             Y
# 22            2             Y
# 23           30             X
# 24           29             Y
# 25           28             Y
# 26           27             Y
# 27           26             X

# %%
# Merging train_tsc_dem_df with camp_df
train_tsc_dem_camp_df=pd.merge(train_tsc_dem_df,camp_df,left_on='campaign_id',right_on='campaign_id')
test_tsc_dem_camp_df=pd.merge(test_tsc_dem_df,camp_df,left_on='campaign_id',right_on='campaign_id')

# %%
train_tsc_dem_camp_df
# Out:
#             id  campaign_id  coupon_id  customer_id  redemption_status  \
# 0            2           13        116           48                  0
# 1            2           13        116           48                  0
# 2         6959           13        992           48                  0
# 3         6959           13        992           48                  0
# 4         8549           13        150           48                  0
# ...        ...          ...        ...          ...                ...
# 197061  122606           27        400         1378                  0
# 197062  122606           27        400         1378                  0
# 197063  124083           27        728         1378                  0
# 197064  124083           27        728         1378                  0
# 197065  124083           27        728         1378                  0
#
#         quantity  selling_price  other_discount  coupon_discount  rented  \
# 0              2          21.37          -21.37              0.0       0
# 1              1          35.62          -28.14              0.0       0
# 2              2          21.37          -21.37              0.0       0
# 3              1          35.62          -28.14              0.0       0
# 4              2          21.37          -21.37              0.0       0
# ...          ...            ...             ...              ...     ...
# 197061         2          63.40            0.00              0.0       0
# 197062         1         177.74          -35.62              0.0       0
# 197063         1          59.13          -11.75              0.0       0
# 197064         2          63.40            0.00              0.0       0
# 197065         1         177.74          -35.62              0.0       0
#
#         income_bracket campaign_type
# 0                    3             X
# 1                    3             X
# 2                    3             X
# 3                    3             X
# 4                    3             X
# ...                ...           ...
# 197061               8             Y
# 197062               8             Y
# 197063               8             Y
# 197064               8             Y
# 197065               8             Y
#
# [197066 rows x 12 columns]

# %%
test_tsc_dem_camp_df
# Out:
#             id  campaign_id  coupon_id  customer_id  quantity  selling_price  \
# 0            3           22        869          967         1         302.41
# 1            3           22        869          967         1         117.19
# 2            3           22        869          967         2         234.38
# 3            3           22        869          967         1          53.43
# 4            3           22        869          967         1          95.46
# ...        ...          ...        ...          ...       ...            ...
# 155624  123403           24         42         1424         1          88.69
# 155625  123403           24         42         1424         2         142.12
# 155626  123403           24         42         1424         1          24.58
# 155627  123403           24         42         1424         1          74.45
# 155628  123403           24         42         1424         2         142.48
#
#         other_discount  coupon_discount  rented  income_bracket campaign_type
# 0                 0.00              0.0       0               5             X
# 1                -7.48              0.0       0               5             X
# 2               -28.50              0.0       0               5             X
# 3               -10.33              0.0       0               5             X
# 4                 0.00              0.0       0               5             X
# ...                ...              ...     ...             ...           ...
# 155624            0.00              0.0       0               5             Y
# 155625         -142.12              0.0       0               5             Y
# 155626          -10.69              0.0       0               5             Y
# 155627            0.00              0.0       0               5             Y
# 155628            0.00              0.0       0               5             Y
#
# [155629 rows x 11 columns]

# %%
#Coupon item mapping Dataset
cpn_map_df=pd.read_csv('/kaggle/input/predicting-coupon-redemption/train/coupon_item_mapping.csv')
cpn_map_df
# Out:
#        coupon_id  item_id
# 0            105       37
# 1            107       75
# 2            494       76
# 3            522       77
# 4            518       77
# ...          ...      ...
# 92658         32    69268
# 92659         32    68502
# 92660         32    68612
# 92661         33    71390
# 92662         31    70030
#
# [92663 rows x 2 columns]

# %%
cpn_map_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92663 entries, 0 to 92662
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   coupon_id  92663 non-null  int64
#  1   item_id    92663 non-null  int64
# dtypes: int64(2)
# memory usage: 1.4 MB

# %%
# Item Dataset
item_df=pd.read_csv('/kaggle/input/predicting-coupon-redemption/train/item_data.csv')
item_df
# Out:
#        item_id  brand   brand_type        category
# 0            1      1  Established         Grocery
# 1            2      1  Established   Miscellaneous
# 2            3     56        Local          Bakery
# 3            4     56        Local         Grocery
# 4            5     56        Local         Grocery
# ...        ...    ...          ...             ...
# 74061    74062   5490  Established  Pharmaceutical
# 74062    74063   5497  Established  Pharmaceutical
# 74063    74064   5497  Established  Pharmaceutical
# 74064    74065   5520  Established  Pharmaceutical
# 74065    74066   5194  Established         Grocery
#
# [74066 rows x 4 columns]

# %%
item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74066 entries, 0 to 74065
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   item_id     74066 non-null  int64
#  1   brand       74066 non-null  int64
#  2   brand_type  74066 non-null  object
#  3   category    74066 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 2.3+ MB

# %%
# Merging coupon item mapping and item dataset
cpn_item_df=pd.merge(cpn_map_df,item_df,left_on='item_id',right_on='item_id')
cpn_item_df
# Out:
#        coupon_id  item_id  brand   brand_type          category
# 0            105       37     56        Local           Grocery
# 1              6       37     56        Local           Grocery
# 2             22       37     56        Local           Grocery
# 3             31       37     56        Local           Grocery
# 4            107       75     56        Local           Grocery
# ...          ...      ...    ...          ...               ...
# 92658         33    68764   3867  Established              Meat
# 92659         29    74013   5383  Established     Miscellaneous
# 92660         29    71965   4554  Established     Miscellaneous
# 92661         29    67815   4985  Established  Flowers & Plants
# 92662         33    68920   3865  Established              Meat
#
# [92663 rows x 5 columns]

# %%
# Selecting features with high importance only
cpn_item_df= cpn_item_df[['coupon_id','brand']]
cpn_item_df
# Out:
#        coupon_id  brand
# 0            105     56
# 1              6     56
# 2             22     56
# 3             31     56
# 4            107     56
# ...          ...    ...
# 92658         33   3867
# 92659         29   5383
# 92660         29   4554
# 92661         29   4985
# 92662         33   3865
#
# [92663 rows x 2 columns]

# %%
# Merging train_tsc_dem_camp_df with cpn_item_df
train_tsc_dem_camp_cpn_df = pd.merge(train_tsc_dem_camp_df,cpn_item_df,left_on='coupon_id',right_on='coupon_id')
# Merging test_tsc_dem_camp_df with cpn_item_df
test_tsc_dem_camp_cpn_df = pd.merge(test_tsc_dem_camp_df, cpn_item_df, left_on='coupon_id', right_on='coupon_id')

# %%
train_tsc_dem_camp_cpn_df
# Out:
#              id  campaign_id  coupon_id  customer_id  redemption_status  \
# 0             2           13        116           48                  0
# 1             2           13        116           48                  0
# 2             2           13        116           48                  0
# 3             2           13        116           48                  0
# 4             2           13        116           48                  0
# ...         ...          ...        ...          ...                ...
# 16958470  14614           27        405         1378                  0
# 16958471  14614           27        405         1378                  0
# 16958472  14614           27        405         1378                  0
# 16958473  14614           27        405         1378                  0
# 16958474  14614           27        405         1378                  0
#
#           quantity  selling_price  other_discount  coupon_discount  rented  \
# 0                2          21.37          -21.37              0.0       0
# 1                2          21.37          -21.37              0.0       0
# 2                2          21.37          -21.37              0.0       0
# 3                1          35.62          -28.14              0.0       0
# 4                1          35.62          -28.14              0.0       0
# ...            ...            ...             ...              ...     ...
# 16958470         1         177.74          -35.62              0.0       0
# 16958471         1         177.74          -35.62              0.0       0
# 16958472         1         177.74          -35.62              0.0       0
# 16958473         1         177.74          -35.62              0.0       0
# 16958474         1         177.74          -35.62              0.0       0
#
#           income_bracket campaign_type  brand
# 0                      3             X     56
# 1                      3             X     56
# 2                      3             X     56
# 3                      3             X     56
# 4                      3             X     56
# ...                  ...           ...    ...
# 16958470               8             Y     57
# 16958471               8             Y     57
# 16958472               8             Y     57
# 16958473               8             Y     57
# 16958474               8             Y     57
#
# [16958475 rows x 13 columns]

# %%
test_tsc_dem_camp_cpn_df
# Out:
#              id  campaign_id  coupon_id  customer_id  quantity  selling_price  \
# 0             3           22        869          967         1         302.41
# 1             3           22        869          967         1         302.41
# 2             3           22        869          967         1         302.41
# 3             3           22        869          967         1         302.41
# 4             3           22        869          967         1         302.41
# ...         ...          ...        ...          ...       ...            ...
# 16240426  42343           24         43         1424         2         142.48
# 16240427  42343           24         43         1424         2         142.48
# 16240428  42343           24         43         1424         2         142.48
# 16240429  42343           24         43         1424         2         142.48
# 16240430  42343           24         43         1424         2         142.48
#
#           other_discount  coupon_discount  rented  income_bracket  \
# 0                    0.0              0.0       0               5
# 1                    0.0              0.0       0               5
# 2                    0.0              0.0       0               5
# 3                    0.0              0.0       0               5
# 4                    0.0              0.0       0               5
# ...                  ...              ...     ...             ...
# 16240426             0.0              0.0       0               5
# 16240427             0.0              0.0       0               5
# 16240428             0.0              0.0       0               5
# 16240429             0.0              0.0       0               5
# 16240430             0.0              0.0       0               5
#
#          campaign_type  brand
# 0                    X   1075
# 1                    X   1075
# 2                    X   1075
# 3                    X   1075
# 4                    X   1075
# ...                ...    ...
# 16240426             Y   5147
# 16240427             Y   2074
# 16240428             Y   2074
# 16240429             Y   2074
# 16240430             Y   1300
#
# [16240431 rows x 12 columns]

# %%
#One hot encoding
training_data=pd.get_dummies(train_tsc_dem_camp_cpn_df)
testing_data=pd.get_dummies(test_tsc_dem_camp_cpn_df)
final_train,final_test=training_data.align(testing_data,join='inner',axis=1)

# %%
final_train.columns
# Out:
# Index(['id', 'campaign_id', 'coupon_id', 'customer_id', 'quantity',
#        'selling_price', 'other_discount', 'coupon_discount', 'rented',
#        'income_bracket', 'brand', 'campaign_type_X', 'campaign_type_Y'],
#       dtype='object')

# %%
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.model_selection import cross_val_score

#X=final_train[['id', 'campaign_id', 'coupon_id', 'customer_id', 'quantity',
#       'selling_price', 'other_discount', 'coupon_discount', 'rented',
#       'income_bracket', 'brand', 'campaign_type_X', 'campaign_type_Y']]
#y=training_data['redemption_status']

#model=RandomForestClassifier(n_estimators=10).fit(X,y)

#cv_scores=cross_val_score(model,X,y,cv=10)

#print('cross validation scores:',cv_scores,'\n','mean of cross validation scores:',np.mean(cv_scores))
